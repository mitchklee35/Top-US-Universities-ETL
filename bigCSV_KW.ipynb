# %%
from splinter import Browser
from splinter.exceptions import ElementDoesNotExist
from bs4 import BeautifulSoup
import pandas as pd
import requests

# %%
# Save file path to variable
bigColData_csv = "resources/top25_bigData.csv"

# %%
# Read with Pandas
bigColData_raw = pd.read_csv(bigColData_csv, low_memory=False)
pd.options.display.max_columns = 2000
bigColData_raw
# Out:
#     UNITID    OPEID  OPEID6                                           INSTNM  \
# 0   104179   108300    1083                            University of Arizona
# 1   110404   113100    1131               California Institute of Technology
# 2   110635   131200    1312                University of California-Berkeley
# 3   110644   131300    1313                   University of California-Davis
# 4   110662   131500    1315             University of California-Los Angeles
# 5   110680   131700    1317               University of California-San Diego
# 6   110699   131900    1319           University of California-San Francisco
# 7   110705   132000    1320           University of California-Santa Barbara
# 8   123961   132800    1328                University of Southern California
# 9   126614   137000    1370                   University of Colorado Boulder
# 10  130794   142600    1426                                  Yale University
# ...

# %%
INSTNM = bigColData_raw ['INSTNM']
CITY = bigColData_raw ['CITY']
STABBR = bigColData_raw ['STABBR']
INSTURL = bigColData_raw ['INSTURL']
OMENRUP_PARTTIME_POOLED_SUPP = bigColData_raw ['OMENRUP_PARTTIME_POOLED_SUPP']
FTFTPCTPELL = bigColData_raw ['FTFTPCTPELL']
FTFTPCTFLOAN = bigColData_raw ['FTFTPCTFLOAN']
UG12MN = bigColData_raw ['UG12MN']
G12MN = bigColData_raw ['G12MN']
SCUGFFN = bigColData_raw ['SCUGFFN']
POOLYRS_FTFTAIDPCT = bigColData_raw ['POOLYRS_FTFTAIDPCT']
FTFTPCTPELL_POOLED_SUPP = bigColData_raw ['FTFTPCTPELL_POOLED_SUPP']
FTFTPCTFLOAN_POOLED_SUPP = bigColData_raw ['FTFTPCTFLOAN_POOLED_SUPP']
SCUGFFN_POOLED = bigColData_raw ['SCUGFFN_POOLED']
ADM_RATE_ALL = bigColData_raw ['ADM_RATE_ALL']
SAT_AVG_ALL = bigColData_raw ['SAT_AVG_ALL']
COSTT4_A = bigColData_raw ['COSTT4_A']
TUITIONFEE_IN = bigColData_raw ['TUITIONFEE_IN']
TUITIONFEE_OUT = bigColData_raw ['TUITIONFEE_OUT']
UGDS = bigColData_raw ['UGDS']
UGDS_WHITE = bigColData_raw ['UGDS_WHITE']
UGDS_BLACK = bigColData_raw ['UGDS_BLACK']
UGDS_HISP = bigColData_raw ['UGDS_HISP']
UGDS_ASIAN = bigColData_raw ['UGDS_ASIAN']
UGDS_AIAN = bigColData_raw ['UGDS_AIAN']
UGDS_NHPI = bigColData_raw ['UGDS_NHPI']
UGDS_2MOR = bigColData_raw ['UGDS_2MOR']
UGDS_NRA = bigColData_raw ['UGDS_NRA']
UGDS_UNKN = bigColData_raw ['UGDS_UNKN']

# %%
bigColData_df = pd.DataFrame({'INSTNM':INSTNM,
                             'City':CITY,
                             'State':STABBR,
                             'URL':INSTURL,
                              'In-state tuition & fees':TUITIONFEE_IN,
                              'Out-of-state tuition & fees':TUITIONFEE_OUT,
                              'Avg cost of attendance/4ys':COSTT4_A,
                              '% FT Pell':FTFTPCTPELL,
                              '% FT Stu Loan':FTFTPCTFLOAN,
                              'Admission Rate':ADM_RATE_ALL,
                              'Avg SAT score ':SAT_AVG_ALL,
                              'Total undergrad enrollment':UGDS,
                              'Undergrad ethnicity-white':UGDS_WHITE,
                              'Undergrad ethnicity-black':UGDS_BLACK,
                              'Undergrad ethnicity-hispanic':UGDS_HISP,
                              'Undergrad ethnicity-asian':UGDS_ASIAN,
                              'Undergrad ethnicity-American Indian':UGDS_AIAN,
                              'Undergrad ethnicity-Native Hawaiian/Pacific Islander':UGDS_NHPI,
                              'Undergrad ethnicity-':UGDS_2MOR,
                              'Undergrad ethnicity-':UGDS_NRA,
                              'UGDS_NRA':UGDS_NRA,
                              'UGDS_UNKN':UGDS_UNKN,
                              'Undergrad enrollment, last 12 mo':UG12MN,
                              'Grad enrollment, last 12 mo':G12MN,
})

bigColData_df
# Out:
#                                              INSTNM             City State  \
# 0                             University of Arizona           Tucson    AZ
# 1                California Institute of Technology         Pasadena    CA
# 2                 University of California-Berkeley         Berkeley    CA
# 3                    University of California-Davis            Davis    CA
# 4              University of California-Los Angeles      Los Angeles    CA
# 5                University of California-San Diego         La Jolla    CA
# 6            University of California-San Francisco    San Francisco    CA
# 7            University of California-Santa Barbara    Santa Barbara    CA
# 8                 University of Southern California      Los Angeles    CA
# 9                    University of Colorado Boulder          Boulder    CO
# 10                                  Yale University        New Haven    CT
# ...

# %%
kegColData_csv = "resources/kaggle_top50.csv"
kagColData_raw = pd.read_csv(bigColData_csv, low_memory=False)
pd.options.display.max_columns = 2000
kagColData_raw
# Out:
#     world_rank                                           INSTNM country  \
# 0            1                               Harvard University     USA
# 1            2                              Stanford University     USA
# 2            3            Massachusetts Institute of Technology     USA
# 3            6                              Columbia University     USA
# 4            7                University of California-Berkeley     USA
# 5            8                            University of Chicago     USA
# 6            9                             Princeton University     USA
# 7           10                               Cornell University     USA
# 8           11                                  Yale University     USA
# 9           12               California Institute of Technology     USA
# 10          14                       University of Pennsylvania     USA
# 11          15             University of California-Los Angeles     USA
# ...

# %%
merge_table = pd.merge(bigColData_df, kagColData_raw, on="INSTNM")
merge_table
# Out:
#                                              INSTNM             City State  \
# 0                             University of Arizona           Tucson    AZ
# 1                California Institute of Technology         Pasadena    CA
# 2                 University of California-Berkeley         Berkeley    CA
# 3                    University of California-Davis            Davis    CA
# 4              University of California-Los Angeles      Los Angeles    CA
# 5                University of California-San Diego         La Jolla    CA
# 6            University of California-San Francisco    San Francisco    CA
# 7            University of California-Santa Barbara    Santa Barbara    CA
# 8                 University of Southern California      Los Angeles    CA
# 9                    University of Colorado Boulder          Boulder    CO
# 10                                  Yale University        New Haven    CT
# ...
